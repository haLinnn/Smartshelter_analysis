# %%
import pandas as pd
import numpy as np

# %%
busstop_df = pd.read_csv('../data/인천광역시_버스정류장 사물주소 현황_20220321.csv',encoding='cp949')
bupyeong_busstop_df = busstop_df[busstop_df['시군구'] == '부평구']
bupyeong_busstop_df.head()
# Out:
#         순번  시군구           사물명       고유번호                          사물주소  \
# 3092  3093  부평구      진산과학고등학교  166000915       인천광역시 부평구 굴포로 208 버스정류장
# 3093  3094  부평구  삼산주공1단지(상가앞)  166000908       인천광역시 부평구 평천로 443 버스정류장
# 3094  3095  부평구      희망체육공원입구  166000912       인천광역시 부평구 경인로 840 버스정류장
# 3095  3096  부평구  인천성모병원종점지주차장  166000919        인천광역시 부평구 동수로 68 버스정류장
# 3096  3097  부평구   열우물보조경기장주차장  166000916  인천광역시 부평구 열우물로150번길 64 버스정류장
#
#          진행상태    사물주소 확정일
# 3092  사물주소 확정  2022-03-08
# 3093  사물주소 확정  2021-10-05
# 3094  사물주소 확정  2021-08-13
# 3095  사물주소 확정  2021-08-13
# 3096  사물주소 확정  2021-08-13

# %%
len(bupyeong_busstop_df)
# Out:
# 681

# %%
bupyeong_busstop_df.rename(columns = {'고유번호':'정류소아이디'}, inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_5256\2508578209.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bupyeong_busstop_df.rename(columns = {'고유번호':'정류소아이디'}, inplace=True)

# %%
bupyeong_busstop_df.head()
# Out:
#         순번  시군구           사물명     정류소아이디                          사물주소  \
# 3092  3093  부평구      진산과학고등학교  166000915       인천광역시 부평구 굴포로 208 버스정류장
# 3093  3094  부평구  삼산주공1단지(상가앞)  166000908       인천광역시 부평구 평천로 443 버스정류장
# 3094  3095  부평구      희망체육공원입구  166000912       인천광역시 부평구 경인로 840 버스정류장
# 3095  3096  부평구  인천성모병원종점지주차장  166000919        인천광역시 부평구 동수로 68 버스정류장
# 3096  3097  부평구   열우물보조경기장주차장  166000916  인천광역시 부평구 열우물로150번길 64 버스정류장
#
#          진행상태    사물주소 확정일
# 3092  사물주소 확정  2022-03-08
# 3093  사물주소 확정  2021-10-05
# 3094  사물주소 확정  2021-08-13
# 3095  사물주소 확정  2021-08-13
# 3096  사물주소 확정  2021-08-13

# %%
bus_df = pd.read_csv('../data/인천광역시_버스노선별 정류장 현황_20220512.csv', encoding='cp949')
bus_df
# Out:
#              기준일자   회사명   회사아이디  노선번호      노선아이디  순번         정류소명  정류소번호  \
# 0      2022-05-12  강인교통  166012   302  165000067   1       십정동차고지  40913
# 1      2022-05-12  강인교통  166012   302  165000067   2        십정사거리  40029
# 2      2022-05-12  강인교통  166012   302  165000067   3       선린감리교회  40043
# 3      2022-05-12  강인교통  166012   302  165000067   4        백영아파트  40058
# 4      2022-05-12  강인교통  166012   302  165000067   5          상정고  40069
# ...           ...   ...     ...   ...        ...  ..          ...    ...
# 24185  2022-05-12  해성운수  168007  순환51  163000001  16       구월도매시장  39192
# 24186  2022-05-12  해성운수  168007  순환51  163000001  17        성리중학교  39979
# 24187  2022-05-12  해성운수  168007  순환51  163000001  18        팬더아파트  39980
# 24188  2022-05-12  해성운수  168007  순환51  163000001  19  구월아시아드2단지정문  39981
# 24189  2022-05-12  해성운수  168007  순환51  163000001  20    구월아시아드1단지  39913
#
#           정류소아이디  아이에스씨 아이디  정류소구간거리  정류소간누적거리 주요경유지여부 상_하행
# ...

# %%
merge_df = pd.merge(bupyeong_busstop_df, bus_df, how='inner', on='정류소아이디')
merge_df
# Out:
#       순번_x  시군구           사물명     정류소아이디                     사물주소     진행상태  \
# 0     3093  부평구      진산과학고등학교  166000915  인천광역시 부평구 굴포로 208 버스정류장  사물주소 확정
# 1     3093  부평구      진산과학고등학교  166000915  인천광역시 부평구 굴포로 208 버스정류장  사물주소 확정
# 2     3093  부평구      진산과학고등학교  166000915  인천광역시 부평구 굴포로 208 버스정류장  사물주소 확정
# 3     3094  부평구  삼산주공1단지(상가앞)  166000908  인천광역시 부평구 평천로 443 버스정류장  사물주소 확정
# 4     3094  부평구  삼산주공1단지(상가앞)  166000908  인천광역시 부평구 평천로 443 버스정류장  사물주소 확정
# ...    ...  ...           ...        ...                      ...      ...
# 2483  3773  부평구         동암사거리  166000001  인천광역시 부평구 백범로 453 버스정류장  사물주소 확정
# 2484  3773  부평구         동암사거리  166000001  인천광역시 부평구 백범로 453 버스정류장  사물주소 확정
# 2485  3773  부평구         동암사거리  166000001  인천광역시 부평구 백범로 453 버스정류장  사물주소 확정
# 2486  3773  부평구         동암사거리  166000001  인천광역시 부평구 백범로 453 버스정류장  사물주소 확정
# 2487  3773  부평구         동암사거리  166000001  인천광역시 부평구 백범로 453 버스정류장  사물주소 확정
#
# ...

# %%
merge_df['노선번호'].value_counts()
# Out:
# 01월 14일    80
# 556        73
# 526        73
# 558        72
# 103        67
#            ..
# 533         2
# 306         2
# 306A        1
# 1500        1
# 62          1
# Name: 노선번호, Length: 95, dtype: int64

# %%
merge_df[merge_df['정류소번호'] == 40080]
# Out:
#       순번_x  시군구  사물명     정류소아이디                    사물주소     진행상태    사물주소 확정일  \
# 2250  3713  부평구  백운역  166000080  인천광역시 부평구 마장로 51 버스정류장  사물주소 확정  2020-05-14
# 2251  3713  부평구  백운역  166000080  인천광역시 부평구 마장로 51 버스정류장  사물주소 확정  2020-05-14
# 2252  3713  부평구  백운역  166000080  인천광역시 부평구 마장로 51 버스정류장  사물주소 확정  2020-05-14
# 2253  3713  부평구  백운역  166000080  인천광역시 부평구 마장로 51 버스정류장  사물주소 확정  2020-05-14
# 2254  3713  부평구  백운역  166000080  인천광역시 부평구 마장로 51 버스정류장  사물주소 확정  2020-05-14
# 2255  3713  부평구  백운역  166000080  인천광역시 부평구 마장로 51 버스정류장  사물주소 확정  2020-05-14
# 2256  3713  부평구  백운역  166000080  인천광역시 부평구 마장로 51 버스정류장  사물주소 확정  2020-05-14
#
#             기준일자      회사명   회사아이디     노선번호      노선아이디  순번_y 정류소명  정류소번호  \
# 2250  2022-05-12     공영급행  161009  01월 14일  165000018    20  백운역  40080
# 2251  2022-05-12     동화운수  167001        2  165000002    25  백운역  40080
# 2252  2022-05-12     미래교통  166011    111-2  165000180    72  백운역  40080
# ...

# %%
merge_df[merge_df['노선번호'].str.contains('월')]  # 노선번호가 잘못들어가있음
# Out:
#       순번_x  시군구              사물명     정류소아이디                         사물주소  \
# 17    3098  부평구  산곡여자중학교(마장로삼거리)  166000911      인천광역시 부평구 마장로 212 버스정류장
# 24    3101  부평구     부평역화성파크드림아파트  166000805       인천광역시 부평구 동수로 76 버스정류장
# 31    3102  부평구     부평역화성파크드림아파트  166000804       인천광역시 부평구 동수로 83 버스정류장
# 57    3116  부평구            한양아파트  166000905  인천광역시 부평구 마장로269번길 44 버스정류장
# 60    3121  부평구        풍림아파트104동  166000899       인천광역시 부평구 항동로 96 버스정류장
# ...    ...  ...              ...        ...                          ...
# 2384  3740  부평구           선린감리교회  166000047    인천광역시 부평구 경원대로 1053 버스정류장
# 2417  3753  부평구            십정사거리  166000033    인천광역시 부평구 경원대로 1029 버스정류장
# 2439  3756  부평구            십정사거리  166000029    인천광역시 부평구 경원대로 1026 버스정류장
# 2455  3764  부평구      수출산업단지6공단입구  166000010    인천광역시 부평구 경원대로 1002 버스정류장
# 2458  3765  부평구      수출산업단지6공단입구  166000009     인천광역시 부평구 경원대로 999 버스정류장
#
#          진행상태    사물주소 확정일        기준일자   회사명   회사아이디     노선번호      노선아이디  순번_y  \
# ...

# %%
merge_df[merge_df['노선번호'] == '01월 24일']  # 노선번호가 잘못들어가있음
# Out:
#       순번_x  시군구              사물명     정류소아이디                         사물주소  \
# 17    3098  부평구  산곡여자중학교(마장로삼거리)  166000911      인천광역시 부평구 마장로 212 버스정류장
# 57    3116  부평구            한양아파트  166000905  인천광역시 부평구 마장로269번길 44 버스정류장
# 291   3189  부평구       굴포천역(롯데마트)  166000815      인천광역시 부평구 장제로 251 버스정류장
# 298   3190  부평구       굴포천역(롯데마트)  166000814      인천광역시 부평구 장제로 252 버스정류장
# 303   3191  부평구      갈산주공1단지105동  166000813      인천광역시 부평구 장제로 321 버스정류장
# 317   3200  부평구          삼산주공7단지  166000801      인천광역시 부평구 체육관로 21 버스정류장
# 403   3212  부평구            부원중학교  166000789    인천광역시 부평구 경원대로 1338 버스정류장
# 420   3213  부평구            현대아파트  166000788    인천광역시 부평구 경원대로 1250 버스정류장
# 435   3215  부평구            삼보아파트  166000786      인천광역시 부평구 원적로 291 버스정류장
# 449   3217  부평구            나누리병원  166000784      인천광역시 부평구 장제로 154 버스정류장
# 518   3254  부평구            삼산사거리  166000691      인천광역시 부평구 장제로 351 버스정류장
# 621   3280  부평구            순복음교회  166000661      인천광역시 부평구 장제로 389 버스정류장
# ...

# %%
merge_df.loc[merge_df.노선번호=='01월 24일','노선번호']='24-1번'
merge_df.loc[merge_df.노선번호=='Jan-67','노선번호']='67-1번'
merge_df.loc[merge_df.노선번호=='01월 14일','노선번호']='14-1번'
merge_df.loc[merge_df.노선번호=='01월 16일','노선번호']='16-1번'
merge_df.loc[merge_df.노선번호=='03월 02일','노선번호']='3-2번'
merge_df.loc[merge_df.노선번호=='Jan-43','노선번호']='43-1번'

# %%
merge_df.to_csv('../data/전처리데이터/부평구 버스.csv', encoding = 'cp949', index=None)

# %%
merge_df
# Out:
#       순번_x  시군구           사물명     정류소아이디                     사물주소     진행상태  \
# 0     3093  부평구      진산과학고등학교  166000915  인천광역시 부평구 굴포로 208 버스정류장  사물주소 확정
# 1     3093  부평구      진산과학고등학교  166000915  인천광역시 부평구 굴포로 208 버스정류장  사물주소 확정
# 2     3093  부평구      진산과학고등학교  166000915  인천광역시 부평구 굴포로 208 버스정류장  사물주소 확정
# 3     3094  부평구  삼산주공1단지(상가앞)  166000908  인천광역시 부평구 평천로 443 버스정류장  사물주소 확정
# 4     3094  부평구  삼산주공1단지(상가앞)  166000908  인천광역시 부평구 평천로 443 버스정류장  사물주소 확정
# ...    ...  ...           ...        ...                      ...      ...
# 2483  3773  부평구         동암사거리  166000001  인천광역시 부평구 백범로 453 버스정류장  사물주소 확정
# 2484  3773  부평구         동암사거리  166000001  인천광역시 부평구 백범로 453 버스정류장  사물주소 확정
# 2485  3773  부평구         동암사거리  166000001  인천광역시 부평구 백범로 453 버스정류장  사물주소 확정
# 2486  3773  부평구         동암사거리  166000001  인천광역시 부평구 백범로 453 버스정류장  사물주소 확정
# 2487  3773  부평구         동암사거리  166000001  인천광역시 부평구 백범로 453 버스정류장  사물주소 확정
#
# ...

# %%
df = merge_df[['사물명','정류소아이디','사물주소','노선번호','노선아이디','정류소번호','정류소구간거리']]
df
# Out:
#                사물명     정류소아이디                     사물주소   노선번호      노선아이디  \
# 0         진산과학고등학교  166000915  인천광역시 부평구 굴포로 208 버스정류장    565  165000112
# 1         진산과학고등학교  166000915  인천광역시 부평구 굴포로 208 버스정류장    555  165000101
# 2         진산과학고등학교  166000915  인천광역시 부평구 굴포로 208 버스정류장    558  165000104
# 3     삼산주공1단지(상가앞)  166000908  인천광역시 부평구 평천로 443 버스정류장     10  165000013
# 4     삼산주공1단지(상가앞)  166000908  인천광역시 부평구 평천로 443 버스정류장     34  165000033
# ...            ...        ...                      ...    ...        ...
# 2483         동암사거리  166000001  인천광역시 부평구 백범로 453 버스정류장  103-1  165000216
# 2484         동암사거리  166000001  인천광역시 부평구 백범로 453 버스정류장     42  165000039
# 2485         동암사거리  166000001  인천광역시 부평구 백범로 453 버스정류장    592  165000132
# 2486         동암사거리  166000001  인천광역시 부평구 백범로 453 버스정류장    304  165000389
# 2487         동암사거리  166000001  인천광역시 부평구 백범로 453 버스정류장     62  165000043
#
#       정류소번호  정류소구간거리
# 0     40915    238.0
# 1     40915    238.0
# 2     40915    238.0
# ...

# %%
df.rename(columns={'사물명':'정류소명','사물주소':'정류소주소'},inplace=True)
df
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_5256\2262766595.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'사물명':'정류소명','사물주소':'정류소주소'},inplace=True)
#               정류소명     정류소아이디                    정류소주소   노선번호      노선아이디  \
# 0         진산과학고등학교  166000915  인천광역시 부평구 굴포로 208 버스정류장    565  165000112
# 1         진산과학고등학교  166000915  인천광역시 부평구 굴포로 208 버스정류장    555  165000101
# 2         진산과학고등학교  166000915  인천광역시 부평구 굴포로 208 버스정류장    558  165000104
# 3     삼산주공1단지(상가앞)  166000908  인천광역시 부평구 평천로 443 버스정류장     10  165000013
# 4     삼산주공1단지(상가앞)  166000908  인천광역시 부평구 평천로 443 버스정류장     34  165000033
# ...            ...        ...                      ...    ...        ...
# 2483         동암사거리  166000001  인천광역시 부평구 백범로 453 버스정류장  103-1  165000216
# ...

# %%
df.to_csv('../data/전처리데이터/부평구 버스.csv', encoding = 'cp949', index=None)

# %%
df
# Out:
#               정류소명     정류소아이디                    정류소주소   노선번호      노선아이디  \
# 0         진산과학고등학교  166000915  인천광역시 부평구 굴포로 208 버스정류장    565  165000112
# 1         진산과학고등학교  166000915  인천광역시 부평구 굴포로 208 버스정류장    555  165000101
# 2         진산과학고등학교  166000915  인천광역시 부평구 굴포로 208 버스정류장    558  165000104
# 3     삼산주공1단지(상가앞)  166000908  인천광역시 부평구 평천로 443 버스정류장     10  165000013
# 4     삼산주공1단지(상가앞)  166000908  인천광역시 부평구 평천로 443 버스정류장     34  165000033
# ...            ...        ...                      ...    ...        ...
# 2483         동암사거리  166000001  인천광역시 부평구 백범로 453 버스정류장  103-1  165000216
# 2484         동암사거리  166000001  인천광역시 부평구 백범로 453 버스정류장     42  165000039
# 2485         동암사거리  166000001  인천광역시 부평구 백범로 453 버스정류장    592  165000132
# 2486         동암사거리  166000001  인천광역시 부평구 백범로 453 버스정류장    304  165000389
# 2487         동암사거리  166000001  인천광역시 부평구 백범로 453 버스정류장     62  165000043
#
#       정류소번호  정류소구간거리
# 0     40915    238.0
# 1     40915    238.0
# 2     40915    238.0
# ...

# %%
df2 = pd.read_csv('../data/인천광역시_시내버스_노선현황_수정1.csv',encoding='cp949')
df2
# Out:
#        노선번호                   기점  \
# 0         1               진웅\n종점
# 1         2       효성동\n동화운수\n차고지
# 2      2-1번      청라동문\n굿모닝힐\n아파트
# 3      3-2번  무지개\n아파트\n(동남\n아파트)
# 4         4            송도제2\n차고지
# ..      ...                  ...
# 229    790B            장수공영\n차고지
# 230    800A              강화\n터미널
# 231    800B              강화\n터미널
# 232    557A             희망체육공원입구
# 233  인천e음17            운북공영\n차고지
#
#                                                    경유지                  종점  \
# 0    검단지식산업센타, 검단오류역, 왕길역, 원흥아파트, 검단농협, 월드아파트, 원당고,...  인천성모\n병원\n종점지\n주차장
# 1    효성사거리, 청천초등학교, 백마장사거리, 부평시장, 부원중, 백운역, 부평삼거리역,...       월미도\n(시티\n투어)
# 2    해원고, 청라3동행정복지센터, 청라달튼국제학교, 청라역, 청라푸르지오, 가원초, 가...   삼보\n아파트\n(계양\n구청)
# 3    인천뷰티예술고등학교, 동막역, 유수지길, 대경화성, 미래테크원, 호구포역, 논현3단...      아시아드주경기장\n(동문)
# 4    인천가톨릭대, 캠퍼스타운역, 동춘동종점, 연수구청, 힘찬병원, 동남스포피아, 인천여...             가좌동\n차고
# ..                                                 ...                 ...
# ...

# %%
df2.drop(['기점','종점','배차간격\n최소(분)','배차간격\n최대(분)'],axis=1,inplace=True)
df2
# Out:
#        노선번호                                                경유지  배차간격 평균(분)
# 0         1  검단지식산업센타, 검단오류역, 왕길역, 원흥아파트, 검단농협, 월드아파트, 원당고,...          16
# 1         2  효성사거리, 청천초등학교, 백마장사거리, 부평시장, 부원중, 백운역, 부평삼거리역,...           8
# 2      2-1번  해원고, 청라3동행정복지센터, 청라달튼국제학교, 청라역, 청라푸르지오, 가원초, 가...          21
# 3      3-2번  인천뷰티예술고등학교, 동막역, 유수지길, 대경화성, 미래테크원, 호구포역, 논현3단...          17
# 4         4  인천가톨릭대, 캠퍼스타운역, 동춘동종점, 연수구청, 힘찬병원, 동남스포피아, 인천여...          14
# ..      ...                                                ...         ...
# 229    790B  (상행) 수현마을, 모래내시장역, 시청후문, 석바위, 제물포역, 숭의역, 옹진군청∼...           0
# 230    800A  (상행) 강화터미널, 김포대학입구, 마송∼수도권제2순환(인천-김포)고속도로∼인하대병...          60
# 231    800B  (상행) 강화터미널, 김포대학입구, 마송, 복합환승센터, 한가람솔터마을, 검단출장소...          65
# 232    557A  신성미소지움, 마을금고, 부평2동주민센터, 부원중학교, 부평역, 부평시장, 우체국앞...          35
# 233  인천e음17  백련산입구, 인천시교육청교육연수원, 넘디, 금호어우림, 영종유승한내들, 레전드호텔,...          52
#
# [234 rows x 3 columns]

# %%
df2.rename(columns={'배차간격 평균(분)':'배차간격'},inplace=True)
df2
# Out:
#        노선번호                                                경유지  배차간격
# 0         1  검단지식산업센타, 검단오류역, 왕길역, 원흥아파트, 검단농협, 월드아파트, 원당고,...    16
# 1         2  효성사거리, 청천초등학교, 백마장사거리, 부평시장, 부원중, 백운역, 부평삼거리역,...     8
# 2      2-1번  해원고, 청라3동행정복지센터, 청라달튼국제학교, 청라역, 청라푸르지오, 가원초, 가...    21
# 3      3-2번  인천뷰티예술고등학교, 동막역, 유수지길, 대경화성, 미래테크원, 호구포역, 논현3단...    17
# 4         4  인천가톨릭대, 캠퍼스타운역, 동춘동종점, 연수구청, 힘찬병원, 동남스포피아, 인천여...    14
# ..      ...                                                ...   ...
# 229    790B  (상행) 수현마을, 모래내시장역, 시청후문, 석바위, 제물포역, 숭의역, 옹진군청∼...     0
# 230    800A  (상행) 강화터미널, 김포대학입구, 마송∼수도권제2순환(인천-김포)고속도로∼인하대병...    60
# 231    800B  (상행) 강화터미널, 김포대학입구, 마송, 복합환승센터, 한가람솔터마을, 검단출장소...    65
# 232    557A  신성미소지움, 마을금고, 부평2동주민센터, 부원중학교, 부평역, 부평시장, 우체국앞...    35
# 233  인천e음17  백련산입구, 인천시교육청교육연수원, 넘디, 금호어우림, 영종유승한내들, 레전드호텔,...    52
#
# [234 rows x 3 columns]

# %%
df2.to_csv('../data/전처리데이터/부평구 버스 배차간격.csv', encoding = 'cp949', index=None)

# %%
df
# Out:
#               정류소명     정류소아이디                    정류소주소   노선번호      노선아이디  \
# 0         진산과학고등학교  166000915  인천광역시 부평구 굴포로 208 버스정류장    565  165000112
# 1         진산과학고등학교  166000915  인천광역시 부평구 굴포로 208 버스정류장    555  165000101
# 2         진산과학고등학교  166000915  인천광역시 부평구 굴포로 208 버스정류장    558  165000104
# 3     삼산주공1단지(상가앞)  166000908  인천광역시 부평구 평천로 443 버스정류장     10  165000013
# 4     삼산주공1단지(상가앞)  166000908  인천광역시 부평구 평천로 443 버스정류장     34  165000033
# ...            ...        ...                      ...    ...        ...
# 2483         동암사거리  166000001  인천광역시 부평구 백범로 453 버스정류장  103-1  165000216
# 2484         동암사거리  166000001  인천광역시 부평구 백범로 453 버스정류장     42  165000039
# 2485         동암사거리  166000001  인천광역시 부평구 백범로 453 버스정류장    592  165000132
# 2486         동암사거리  166000001  인천광역시 부평구 백범로 453 버스정류장    304  165000389
# 2487         동암사거리  166000001  인천광역시 부평구 백범로 453 버스정류장     62  165000043
#
#       정류소번호  정류소구간거리
# 0     40915    238.0
# 1     40915    238.0
# 2     40915    238.0
# ...

# %%
df_bus = df.drop_duplicates(['정류소아이디']) # 중복제거한거 df_bus에 보관

# %%
df_bus
# Out:
#               정류소명     정류소아이디                         정류소주소   노선번호      노선아이디  \
# 0         진산과학고등학교  166000915       인천광역시 부평구 굴포로 208 버스정류장    565  165000112
# 3     삼산주공1단지(상가앞)  166000908       인천광역시 부평구 평천로 443 버스정류장     10  165000013
# 5         희망체육공원입구  166000912       인천광역시 부평구 경인로 840 버스정류장    561  165000107
# 13    인천성모병원종점지주차장  166000919        인천광역시 부평구 동수로 68 버스정류장     79  165000053
# 16     열우물보조경기장주차장  166000916  인천광역시 부평구 열우물로150번길 64 버스정류장  564-1  165000111
# ...            ...        ...                           ...    ...        ...
# 2470           종근당  166000005       인천광역시 부평구 백범로 486 버스정류장  103-1  165000216
# 2471          형제마트  166000004         인천광역시 부평구 정석로 6 버스정류장    564  165000110
# 2472         동암사거리  166000003       인천광역시 부평구 백범로 452 버스정류장    303  165000219
# 2479           종근당  166000002       인천광역시 부평구 백범로 481 버스정류장  103-1  165000216
# 2480         동암사거리  166000001       인천광역시 부평구 백범로 453 버스정류장    303  165000219
#
#       정류소번호  정류소구간거리
# ...

# %%
df_bus.drop(['노선번호'],axis=1, inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_5256\3340447751.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bus.drop(['노선번호'],axis=1, inplace=True)

# %%
df_bus.index
# Out:
# Int64Index([   0,    3,    5,   13,   16,   17,   20,   23,   24,   31,
#             ...
#             2453, 2456, 2459, 2464, 2469, 2470, 2471, 2472, 2479, 2480],
#            dtype='int64', length=645)

# %%
df_bus['인덱스'] = df_bus.index
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_5256\435930094.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bus['인덱스'] = df_bus.index

# %%
df_bus
# Out:
#               정류소명     정류소아이디                         정류소주소      노선아이디  정류소번호  \
# 0         진산과학고등학교  166000915       인천광역시 부평구 굴포로 208 버스정류장  165000112  40915
# 3     삼산주공1단지(상가앞)  166000908       인천광역시 부평구 평천로 443 버스정류장  165000013  40908
# 5         희망체육공원입구  166000912       인천광역시 부평구 경인로 840 버스정류장  165000107  40912
# 13    인천성모병원종점지주차장  166000919        인천광역시 부평구 동수로 68 버스정류장  165000053  40919
# 16     열우물보조경기장주차장  166000916  인천광역시 부평구 열우물로150번길 64 버스정류장  165000111  40916
# ...            ...        ...                           ...        ...    ...
# 2470           종근당  166000005       인천광역시 부평구 백범로 486 버스정류장  165000216  40005
# 2471          형제마트  166000004         인천광역시 부평구 정석로 6 버스정류장  165000110  40004
# 2472         동암사거리  166000003       인천광역시 부평구 백범로 452 버스정류장  165000219  40003
# 2479           종근당  166000002       인천광역시 부평구 백범로 481 버스정류장  165000216  40002
# 2480         동암사거리  166000001       인천광역시 부평구 백범로 453 버스정류장  165000219  40001
#
#       정류소구간거리   인덱스
# ...

# %%
df_bus.to_csv('../data/전처리데이터/부평구 버스_수정.csv', encoding = 'cp949', index=None)

# %%
# df_bus.iloc[1]['인덱스']
for j in range(df_bus.iloc[1]['인덱스']- df_bus.iloc[0]['인덱스']):
    print(df_bus.iloc[0]['인덱스']+j)
# Out:
# 0
# 1
# 2

# %%
df
# Out:
#               정류소명     정류소아이디                    정류소주소   노선번호      노선아이디  \
# 0         진산과학고등학교  166000915  인천광역시 부평구 굴포로 208 버스정류장    565  165000112
# 1         진산과학고등학교  166000915  인천광역시 부평구 굴포로 208 버스정류장    555  165000101
# 2         진산과학고등학교  166000915  인천광역시 부평구 굴포로 208 버스정류장    558  165000104
# 3     삼산주공1단지(상가앞)  166000908  인천광역시 부평구 평천로 443 버스정류장     10  165000013
# 4     삼산주공1단지(상가앞)  166000908  인천광역시 부평구 평천로 443 버스정류장     34  165000033
# ...            ...        ...                      ...    ...        ...
# 2483         동암사거리  166000001  인천광역시 부평구 백범로 453 버스정류장  103-1  165000216
# 2484         동암사거리  166000001  인천광역시 부평구 백범로 453 버스정류장     42  165000039
# 2485         동암사거리  166000001  인천광역시 부평구 백범로 453 버스정류장    592  165000132
# 2486         동암사거리  166000001  인천광역시 부평구 백범로 453 버스정류장    304  165000389
# 2487         동암사거리  166000001  인천광역시 부평구 백범로 453 버스정류장     62  165000043
#
#       정류소번호  정류소구간거리
# 0     40915    238.0
# 1     40915    238.0
# 2     40915    238.0
# ...

# %%
# df.drop_duplicates(['정류소아이디','노선번호'], keep = 'first')
# df

# %%
bus_list=[]
for i in range(len(df_bus)-1): # i는 0부터
    count=[]
    for j in range(df_bus.iloc[i+1]['인덱스'] - df_bus.iloc[i]['인덱스']):
        count.append(df.iloc[df_bus.iloc[i]['인덱스']+j]['노선번호'])
    bus_list.append(count)
    
bus_list.append(['303','304','103','103-1','42','592','62'])
len(bus_list)
# Out:
# 645

# %%
df_bus['노선번호'] = bus_list
df_bus
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_5256\3592299424.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bus['노선번호'] = bus_list
#               정류소명     정류소아이디                         정류소주소      노선아이디  정류소번호  \
# 0         진산과학고등학교  166000915       인천광역시 부평구 굴포로 208 버스정류장  165000112  40915
# 3     삼산주공1단지(상가앞)  166000908       인천광역시 부평구 평천로 443 버스정류장  165000013  40908
# 5         희망체육공원입구  166000912       인천광역시 부평구 경인로 840 버스정류장  165000107  40912
# 13    인천성모병원종점지주차장  166000919        인천광역시 부평구 동수로 68 버스정류장  165000053  40919
# 16     열우물보조경기장주차장  166000916  인천광역시 부평구 열우물로150번길 64 버스정류장  165000111  40916
# ...            ...        ...                           ...        ...    ...
# ...

# %%
df_bus.drop(['인덱스', '정류소구간거리'], axis=1, inplace=True)
df_bus
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_5256\1721648185.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_bus.drop(['인덱스', '정류소구간거리'], axis=1, inplace=True)
#               정류소명     정류소아이디                         정류소주소      노선아이디  정류소번호  \
# 0         진산과학고등학교  166000915       인천광역시 부평구 굴포로 208 버스정류장  165000112  40915
# 3     삼산주공1단지(상가앞)  166000908       인천광역시 부평구 평천로 443 버스정류장  165000013  40908
# 5         희망체육공원입구  166000912       인천광역시 부평구 경인로 840 버스정류장  165000107  40912
# 13    인천성모병원종점지주차장  166000919        인천광역시 부평구 동수로 68 버스정류장  165000053  40919
# 16     열우물보조경기장주차장  166000916  인천광역시 부평구 열우물로150번길 64 버스정류장  165000111  40916
# ...            ...        ...                           ...        ...    ...
# ...

# %%
df_bus.to_csv('../data/전처리데이터/부평구 버스_수정.csv', encoding = 'cp949', index=None)
