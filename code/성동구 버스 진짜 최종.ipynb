# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('../data/전처리데이터/성동구 버스 도로폭.csv', encoding='cp949')

# %%
df
# Out:
#        NODE_ID  ARS-ID            정류소명         위도          경도  버스 수  \
# 0    103000001    4001         답십리역사거리  37.565426  127.054368     6
# 1    103000002    4002  청년회의소.서울새활용플라자  37.561952  127.060479     9
# 2    103000003    4003            장한평역  37.561131  127.066098    10
# 3    103000004    4101           상왕십리역  37.564279  127.029260     5
# 4    103000005    4102           상왕십리역  37.564609  127.028642    11
# ..         ...     ...             ...        ...         ...   ...
# 427  103900293    4911         한양대학교정문  37.557954  127.041932     1
# 428  103900284    4912      한양대학교제2의학관  37.558815  127.041924     1
# 429  103900292    4913       한양대학교동문회관  37.558833  127.041823     1
# 430  103900283    4914         한양대학교정문  37.557771  127.042058     1
# 431  103000508    6507        청계한신휴플러스  37.571710  127.044830     4
#
#                                              버스 노선 리스트  평균 배차 간격  최대 배차 간격  \
# ...

# %%
df['도로폭_숫자'] = df['도로폭'].map({'6m미만':'1',
                             '폭6-8m':'2',
                             '폭8-10m':'3',
                             '폭10-12m':'4',
                             '폭12-15m':'5',
                             '폭15-20m':'6',
                             '폭20-25m':'7',
                             '폭25-30m':'8',
                             '폭30-35m':'9',
                             '폭35-40m':'10',
                             '폭40-50m':'11',
                             '폭50-70m':'12',
                             '폭70m이상':'13'
                             },
                             na_action=None)

# %%
df
# Out:
#        NODE_ID  ARS-ID            정류소명         위도          경도  버스 수  \
# 0    103000001    4001         답십리역사거리  37.565426  127.054368     6
# 1    103000002    4002  청년회의소.서울새활용플라자  37.561952  127.060479     9
# 2    103000003    4003            장한평역  37.561131  127.066098    10
# 3    103000004    4101           상왕십리역  37.564279  127.029260     5
# 4    103000005    4102           상왕십리역  37.564609  127.028642    11
# ..         ...     ...             ...        ...         ...   ...
# 427  103900293    4911         한양대학교정문  37.557954  127.041932     1
# 428  103900284    4912      한양대학교제2의학관  37.558815  127.041924     1
# 429  103900292    4913       한양대학교동문회관  37.558833  127.041823     1
# 430  103900283    4914         한양대학교정문  37.557771  127.042058     1
# 431  103000508    6507        청계한신휴플러스  37.571710  127.044830     4
#
#                                              버스 노선 리스트  평균 배차 간격  최대 배차 간격  \
# ...

# %%
df.to_csv('../data/전처리데이터/성동구 버스 진짜 최종.csv', encoding = 'cp949', index=None)
